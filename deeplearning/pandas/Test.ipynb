# %% [markdown]
# # 삶의 만족도 데이터 준비

# %%
import numpy as np
import pandas as pd

pd.read_csv("oecd_bli.csv", thousands=',')
# Out:
#      LOCATION         Country INDICATOR                          Indicator  \
# 0         AUS       Australia   JE_LMIS           Labour market insecurity
# 1         AUT         Austria   JE_LMIS           Labour market insecurity
# 2         BEL         Belgium   JE_LMIS           Labour market insecurity
# 3         CAN          Canada   JE_LMIS           Labour market insecurity
# 4         CZE  Czech Republic   JE_LMIS           Labour market insecurity
# ...       ...             ...       ...                                ...
# 2364      LTU       Lithuania   WL_EWLH  Employees working very long hours
# 2365      COL        Colombia   WL_EWLH  Employees working very long hours
# 2366      LTU       Lithuania   WL_EWLH  Employees working very long hours
# 2367      COL        Colombia   WL_EWLH  Employees working very long hours
# 2368      LTU       Lithuania   WL_EWLH  Employees working very long hours
#
#      MEASURE Measure INEQUALITY Inequality Unit Code        Unit  \
# ...

# %%
oecd_bli = pd.read_csv("oecd_bli.csv", thousands=',')
oecd_bli = oecd_bli[oecd_bli["INEQUALITY"] == 'TOT'] #불펼등이 Total인 것만
oecd_bli
# Out:
#      LOCATION         Country INDICATOR                          Indicator  \
# 0         AUS       Australia   JE_LMIS           Labour market insecurity
# 1         AUT         Austria   JE_LMIS           Labour market insecurity
# 2         BEL         Belgium   JE_LMIS           Labour market insecurity
# 3         CAN          Canada   JE_LMIS           Labour market insecurity
# 4         CZE  Czech Republic   JE_LMIS           Labour market insecurity
# ...       ...             ...       ...                                ...
# 2350      LTU       Lithuania   SW_LIFS                  Life satisfaction
# 2357      COL        Colombia   PS_REPH                      Homicide rate
# 2358      LTU       Lithuania   PS_REPH                      Homicide rate
# 2363      COL        Colombia   WL_EWLH  Employees working very long hours
# 2364      LTU       Lithuania   WL_EWLH  Employees working very long hours
#
# ...

# %%
#여러 분류로 섞인 행 데이터를 열 데이터로 전환하는 것.
#이 데이터는 각 나라별 지표가 여러 행에 나타나 있다. 지표를 열로 전환하여 하나의 행으로 표현하도록 변환
#Country를 인덱스로 하고,
#Indicator를 열로 하고
#각 열의 값은 Value로 하는
oecd_bli = oecd_bli.pivot(index="Country", columns="Indicator", values="Value")
oecd_bli.head(5)
# Out:
# Indicator  Air pollution  Dwellings without basic facilities  \
# Country
# Australia            5.0                                 NaN
# Austria             16.0                                 0.9
# Belgium             15.0                                 1.9
# Brazil              10.0                                 6.7
# Canada               7.0                                 0.2
#
# Indicator  Educational attainment  Employees working very long hours  \
# Country
# Australia                    81.0                              13.04
# Austria                      85.0                               6.66
# Belgium                      77.0                               4.75
# Brazil                       49.0                               7.13
# Canada                       91.0                               3.69
#
# Indicator  Employment rate  Feeling safe walking alone at night  \
# Country
# Australia             73.0                                 63.5
# ...

# %%
oecd_bli["Life satisfaction"].head()
# Out:
# Country
# Australia    7.3
# Austria      7.1
# Belgium      6.9
# Brazil       6.4
# Canada       7.4
# Name: Life satisfaction, dtype: float64

# %% [markdown]
# # 1인당 GDP 데이터 준비

# %%
gdp_data = pd.read_csv("gdp_per_capita.csv", thousands=',', delimiter='\t', encoding='latin1', na_values='n/a')
gdp_data.head()
# Out:
#                Country                                 Subject Descriptor  \
# 0          Afghanistan  Gross domestic product per capita, current prices
# 1              Albania  Gross domestic product per capita, current prices
# 2              Algeria  Gross domestic product per capita, current prices
# 3               Angola  Gross domestic product per capita, current prices
# 4  Antigua and Barbuda  Gross domestic product per capita, current prices
#
#           Units  Scale                      Country/Series-specific Notes  \
# 0  U.S. dollars  Units  See notes for:  Gross domestic product, curren...
# 1  U.S. dollars  Units  See notes for:  Gross domestic product, curren...
# 2  U.S. dollars  Units  See notes for:  Gross domestic product, curren...
# 3  U.S. dollars  Units  See notes for:  Gross domestic product, curren...
# 4  U.S. dollars  Units  See notes for:  Gross domestic product, curren...
#
#         2015  Estimates Start After
# 0    599.994                 2013.0
# ...

# %%
#inplace는 반환받지 않고 바로 변경하도록 설정
gdp_data.rename(columns={"2015": "GDP per capita"}, inplace=True)
gdp_data.head()
# Out:
#                Country                                 Subject Descriptor  \
# 0          Afghanistan  Gross domestic product per capita, current prices
# 1              Albania  Gross domestic product per capita, current prices
# 2              Algeria  Gross domestic product per capita, current prices
# 3               Angola  Gross domestic product per capita, current prices
# 4  Antigua and Barbuda  Gross domestic product per capita, current prices
#
#           Units  Scale                      Country/Series-specific Notes  \
# 0  U.S. dollars  Units  See notes for:  Gross domestic product, curren...
# 1  U.S. dollars  Units  See notes for:  Gross domestic product, curren...
# 2  U.S. dollars  Units  See notes for:  Gross domestic product, curren...
# 3  U.S. dollars  Units  See notes for:  Gross domestic product, curren...
# 4  U.S. dollars  Units  See notes for:  Gross domestic product, curren...
#
#    GDP per capita  Estimates Start After
# ...

# %%
gdp_data.set_index("Country", inplace=True)
gdp_data.head()
# Out:
#                                                     Subject Descriptor  \
# Country
# Afghanistan          Gross domestic product per capita, current prices
# Albania              Gross domestic product per capita, current prices
# Algeria              Gross domestic product per capita, current prices
# Angola               Gross domestic product per capita, current prices
# Antigua and Barbuda  Gross domestic product per capita, current prices
#
#                             Units  Scale  \
# Country
# Afghanistan          U.S. dollars  Units
# Albania              U.S. dollars  Units
# Algeria              U.S. dollars  Units
# Angola               U.S. dollars  Units
# Antigua and Barbuda  U.S. dollars  Units
#
#                                          Country/Series-specific Notes  \
# Country
# Afghanistan          See notes for:  Gross domestic product, curren...
# Albania              See notes for:  Gross domestic product, curren...
# ...

# %%
full_country_stats = pd.merge(left=oecd_bli, right=gdp_data, left_index=True, right_index=True)
full_country_stats.head()
# Out:
#            Air pollution  Dwellings without basic facilities  \
# Country
# Australia            5.0                                 NaN
# Austria             16.0                                 0.9
# Belgium             15.0                                 1.9
# Brazil              10.0                                 6.7
# Canada               7.0                                 0.2
#
#            Educational attainment  Employees working very long hours  \
# Country
# Australia                    81.0                              13.04
# Austria                      85.0                               6.66
# Belgium                      77.0                               4.75
# Brazil                       49.0                               7.13
# Canada                       91.0                               3.69
#
#            Employment rate  Feeling safe walking alone at night  \
# Country
# Australia             73.0                                 63.5
# ...

# %%
full_country_stats.sort_values(by="GDP per capita", inplace=True)
full_country_stats.head()
# Out:
#               Air pollution  Dwellings without basic facilities  \
# Country
# South Africa           22.0                                37.0
# Colombia               10.0                                23.9
# Brazil                 10.0                                 6.7
# Mexico                 16.0                                25.5
# Russia                 15.0                                14.8
#
#               Educational attainment  Employees working very long hours  \
# Country
# South Africa                    73.0                              18.12
# Colombia                        54.0                              26.56
# Brazil                          49.0                               7.13
# Mexico                          38.0                              28.70
# Russia                          94.0                               0.14
#
#               Employment rate  Feeling safe walking alone at night  \
# Country
# ...

# %%
full_country_stats[["GDP per capita", 'Life satisfaction']].loc["Korea"]
# Out:
# GDP per capita       27195.197
# Life satisfaction        5.900
# Name: Korea, dtype: float64

# %%
sample_data = full_country_stats[["GDP per capita", 'Life satisfaction']]
sample_data
# Out:
#                  GDP per capita  Life satisfaction
# Country
# South Africa           5694.572                4.7
# Colombia               6083.510                6.3
# Brazil                 8669.998                6.4
# Mexico                 9009.280                6.5
# Russia                 9054.914                5.8
# Turkey                 9437.372                5.5
# Hungary               12239.894                5.6
# Poland                12495.334                6.1
# Chile                 13340.905                6.5
# Latvia                13618.569                5.9
# Lithuania             14210.280                5.9
# Slovak Republic       15991.736                6.2
# Czech Republic        17256.918                6.7
# Estonia               17288.083                5.7
# Greece                18064.288                5.4
# Portugal              19121.592                5.4
# Slovenia              20732.482                5.9
# ...

# %%
sample_data.plot(kind='scatter', x="GDP per capita", y='Life satisfaction', figsize=(5,3))

# %%
import os
#이미지 저장 관련
PROJECT_ROOT_DIR = "."
CHAPTER_ID = "fundamentals"
IMAGES_PATH = os.path.join(PROJECT_ROOT_DIR, "images", CHAPTER_ID)
os.makedirs(IMAGES_PATH, exist_ok=True)

def save_fig(fig_id, tight_layout=True, fig_extension="png", resolution=300):
    path = os.path.join(IMAGES_PATH, fig_id + "." + fig_extension)
    print("Saving figure", fig_id)
    if tight_layout:
        plt.tight_layout()
    plt.savefig(path, format=fig_extension, dpi=resolution)

# %%
import matplotlib.pyplot as plt

sample_data.plot(kind='scatter', x="GDP per capita", y='Life satisfaction', figsize=(5,3))
plt.axis([0, 60000, 0, 10])
position_text = {
    "Hungary": (5000, 1),
    "Korea": (18000, 1.7),
    "France": (29000, 2.4),
    "Australia": (40000, 3.0),
    "United States": (52000, 3.8),
}
for country, pos_text in position_text.items():
    pos_data_x, pos_data_y = sample_data.loc[country]
    country = "U.S." if country == "United States" else country
    plt.annotate(country, xy=(pos_data_x, pos_data_y), xytext=pos_text,
            arrowprops=dict(facecolor='black', width=0.5, shrink=0.1, headwidth=5))
    plt.plot(pos_data_x, pos_data_y, "ro")
plt.xlabel("GDP per capita (USD)")
save_fig('money_happy_scatterplot')
plt.show()
# Out:
# Saving figure money_happy_scatterplot

# %%
sample_data.to_csv("lifesat.csv")

# %%
sample_data.loc[list(position_text.keys())]
# Out:
#                GDP per capita  Life satisfaction
# Country
# Hungary             12239.894                5.6
# Korea               27195.197                5.9
# France              37675.006                6.5
# Australia           50961.865                7.3
# United States       55805.204                6.9

# %%
#배열 데이터를 모두 열 방향으로 이어 붙여서 2차원 배열 만들기
print(np.c_[sample_data["GDP per capita"]].shape)

np.c_[sample_data["GDP per capita"]]
# Out:
# (40, 1)
# array([[  5694.572],
#        [  6083.51 ],
#        [  8669.998],
#        [  9009.28 ],
#        [  9054.914],
#        [  9437.372],
#        [ 12239.894],
#        [ 12495.334],
#        [ 13340.905],
#        [ 13618.569],
#        [ 14210.28 ],
#        [ 15991.736],
#        [ 17256.918],
#        [ 17288.083],
#        [ 18064.288],
#        [ 19121.592],
#        [ 20732.482],
#        [ 25864.721],
#        [ 27195.197],
#        [ 29866.581],
#        [ 32485.545],
#        [ 35343.336],
#        [ 37044.891],
#        [ 37675.006],
#        [ 40106.632],
#        [ 40996.511],
#        [ 41973.988],
#        [ 43331.961],
#        [ 43603.115],
#        [ 43724.031],
#        [ 43770.688],
#        [ 49866.266],
#        [ 50854.583],
#        [ 50961.865],
#        [ 51350.744],
#        [ 52114.165],
#        [ 55805.204],
#        [ 74822.106],
#        [ 80675.308],
#        [101994.093]])

# %% [markdown]
# # 사이킷런 회귀 학습

# %%
from sklearn import linear_model

lin1 = linear_model.LinearRegression()
Xsample = np.c_[sample_data["GDP per capita"]]
ysample = np.c_[sample_data["Life satisfaction"]]
lin1.fit(Xsample, ysample)
t0, t1 = lin1.intercept_[0], lin1.coef_[0][0]

# %%
t0, t1
# Out:
# (5.724081771574703, 2.4690442081769255e-05)

# %%
sample_data.plot(kind='scatter', x="GDP per capita", y='Life satisfaction', figsize=(5,3))
plt.xlabel("GDP per capita (USD)")
plt.axis([0, 60000, 0, 10])
X=np.linspace(0, 60000, 1000)
plt.plot(X, t0 + t1*X, "b")
plt.text(5000, 3.1, r"$\theta_0 = 5.72$", fontsize=14, color="b")
plt.text(5000, 2.2, r"$\theta_1 = 2.46 \times 10^{-5}$", fontsize=14, color="b")
save_fig('best_fit_model_plot')
plt.show()
# Out:
# Saving figure best_fit_model_plot

# %%
cyprus_gdp_data = gdp_data.loc["Cyprus"]["GDP per capita"]
print(cyprus_gdp_data)
# Out:
# 22587.49

# %%
cyprus_life_satisfaction = lin1.predict([[cyprus_gdp_data]])
cyprus_life_satisfaction
# Out:
# array([[6.28177689]])
